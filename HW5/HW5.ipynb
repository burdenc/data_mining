# %% [markdown]
# # <p style="text-align: center;">EE 380L: Data Mining</p>
# # <p style="text-align: center;">Assignment 5</p>
# ## <p style="text-align: center;">Total points: 40</p>
# ## <p style="text-align: center;">Due: Thursday, April 24th, submitted via Canvas by 11:59 pm</p>
#
# Your homework should be written in a **Jupyter notebook**. You may work in groups of two if you wish. Only one student per team needs to submit the assignment on Canvas.  But be sure to include name and UTID for both students.  Homework groups will be created and managed through Canvas, so please do not arbitrarily change your homework group.
#
# Also, please make sure your code runs and the graphics (and anything else) are displayed in your notebook before submitting. (%matplotlib inline)

# %% [markdown]
# ## Name: Cassidy Burden
# ## UT EID: cab5534
#
# ## Name: Ryan Meek
# ## UT EID: rjm3263

# %% [markdown]
# # Problem 1 - Random Forest vs Boosting - Regression (15pts)

# %% [markdown]
# In this question, we will compare performance of different ensemble methods for regression problems: [Random Forest](http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html), [Gradient Boosting Regressor](http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.GradientBoostingRegressor.html) (GBR), and [AdaBoost](http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.AdaBoostRegressor.html#sklearn.ensemble.AdaBoostRegressor). We will use the Appliances energy prediction dataset for this problem https://archive.ics.uci.edu/ml/datasets/Appliances+energy+prediction. Use random_state = 42 for the algorithms.
#
# 1. Use a [Random Forest](http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html). Find the best parameters (*n_estimators*) using [GridSearchCV](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html). Report the accuracy of your model in terms of RMSE. (5pts)
#
# 2. Use [Gradient Boosting Regressor](http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.GradientBoostingRegressor.html) (GBR). Find the best parameters (including *n_estimators,* *max_depth* and* learning_rate*), and report corresponding RMSE for each algorithm. (5pts)
#
# 3. Use [AdaBoost](http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.AdaBoostRegressor.html#sklearn.ensemble.AdaBoostRegressor) for predicting the targets. Find the best parameters (*n_estimators*, *learning_rate*). Report the accuracy of your model in terms of RMSE. (5pts)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import (train_test_split,GridSearchCV)
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import (RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor)

# %%
data = pd.read_csv('energydata_complete.csv') 

y = data['Appliances']
X = data.drop(['date','Appliances', 'rv1', 'rv2'], axis = 1)


from dateutil import parser
timeData = np.array(data['date'])

days = []
hours = []
for line in range(len(timeData)):
    day = parser.parse(timeData[line]).weekday()
    hour = parser.parse(timeData[line]).hour
    days.append(day)
    hours.append(hour)
    
X = pd.concat([X, pd.get_dummies(days), pd.get_dummies(hours)], axis = 1)


x_train, x_test, y_train, y_test = train_test_split(X,y,test_size = 0.33, random_state=42)

print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# (13222, 56) (13222,) (6513, 56) (6513,)

# %% [markdown]
# # Solution
# ### Part a

# %%
params = {
    'n_estimators': range(1,500,20)
}
rand_forest_cv = GridSearchCV(RandomForestRegressor(random_state=42), params, cv=5, verbose=2, n_jobs=-1)
rand_forest_cv.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV] n_estimators=1 ..................................................
# [CV] n_estimators=1 ..................................................
# [CV] n_estimators=1 ..................................................
# [CV] n_estimators=1 ..................................................
# [CV] ................................... n_estimators=1, total=   0.6s
# [CV] n_estimators=1 ..................................................
# [CV] ................................... n_estimators=1, total=   0.6s
# [CV] n_estimators=21 .................................................
# [CV] ................................... n_estimators=1, total=   0.7s
# [CV] n_estimators=21 .................................................
# [CV] ................................... n_estimators=1, total=   0.8s
# [CV] n_estimators=21 .................................................
# [CV] ................................... n_estimators=1, total=   0.7s
# [CV] n_estimators=21 .................................................
# [CV] .................................. n_estimators=21, total=  11.4s
# [CV] n_estimators=21 .................................................
# [CV] .................................. n_estimators=21, total=  11.6s
# [CV] n_estimators=41 .................................................
# [CV] .................................. n_estimators=21, total=  11.7s
# [CV] n_estimators=41 .................................................
# [CV] .................................. n_estimators=21, total=  11.4s
# [CV] n_estimators=41 .................................................
# [CV] .................................. n_estimators=21, total=  11.5s
# [CV] n_estimators=41 .................................................
# [CV] .................................. n_estimators=41, total=  22.6s
# [CV] n_estimators=41 .................................................
# [CV] .................................. n_estimators=41, total=  22.7s
# [CV] n_estimators=61 .................................................
# [CV] .................................. n_estimators=41, total=  23.0s
# [CV] n_estimators=61 .................................................
# [CV] .................................. n_estimators=41, total=  22.4s
# [CV] n_estimators=61 .................................................
# [CV] .................................. n_estimators=41, total=  23.3s
# [CV] n_estimators=61 .................................................
# [CV] .................................. n_estimators=61, total=  38.9s
# [CV] n_estimators=61 .................................................
# [CV] .................................. n_estimators=61, total=  40.9s
# [CV] n_estimators=81 .................................................
# [CV] .................................. n_estimators=61, total=  43.4s
# [CV] n_estimators=81 .................................................
# [CV] .................................. n_estimators=61, total=  44.2s
# [CV] n_estimators=81 .................................................
# [CV] .................................. n_estimators=61, total=  41.2s
# [CV] n_estimators=81 .................................................
# [CV] .................................. n_estimators=81, total=  51.8s
# [CV] n_estimators=81 .................................................
# [CV] .................................. n_estimators=81, total=  49.8s
# [CV] n_estimators=101 ................................................
# [CV] .................................. n_estimators=81, total=  48.9s
# [CV] n_estimators=101 ................................................
# [CV] .................................. n_estimators=81, total=  47.8s
# [CV] n_estimators=101 ................................................
# [CV] .................................. n_estimators=81, total=  46.6s
# [CV] n_estimators=101 ................................................
# [CV] ................................. n_estimators=101, total=  56.4s
# [CV] n_estimators=101 ................................................
# [CV] ................................. n_estimators=101, total=  55.5s
# [CV] n_estimators=121 ................................................
# [CV] ................................. n_estimators=101, total=  53.4s
# [CV] n_estimators=121 ................................................
# [CV] ................................. n_estimators=101, total=  55.7s
# [CV] n_estimators=121 ................................................
# [CV] ................................. n_estimators=101, total= 1.1min
# [CV] n_estimators=121 ................................................
# [CV] ................................. n_estimators=121, total= 1.4min
# [CV] n_estimators=121 ................................................
# [CV] ................................. n_estimators=121, total= 1.4min
# [CV] n_estimators=141 ................................................
# [CV] ................................. n_estimators=121, total= 1.3min
# [CV] n_estimators=141 ................................................
# [Parallel(n_jobs=4)]: Done  33 tasks      | elapsed:  5.2min
# [CV] ................................. n_estimators=121, total= 1.1min
# [CV] n_estimators=141 ................................................
# [CV] ................................. n_estimators=121, total= 1.1min
# [CV] n_estimators=141 ................................................
# [CV] ................................. n_estimators=141, total= 1.3min
# [CV] n_estimators=141 ................................................
# [CV] ................................. n_estimators=141, total= 1.3min
# [CV] n_estimators=161 ................................................
# [CV] ................................. n_estimators=141, total= 1.3min
# [CV] n_estimators=161 ................................................
# [CV] ................................. n_estimators=141, total= 1.3min
# [CV] n_estimators=161 ................................................
# [CV] ................................. n_estimators=141, total= 1.3min
# [CV] n_estimators=161 ................................................
# [CV] ................................. n_estimators=161, total= 1.5min
# [CV] n_estimators=161 ................................................
# [CV] ................................. n_estimators=161, total= 1.5min
# [CV] n_estimators=181 ................................................
# [CV] ................................. n_estimators=161, total= 1.5min
# [CV] n_estimators=181 ................................................
# [CV] ................................. n_estimators=161, total= 1.4min
# [CV] n_estimators=181 ................................................
# [CV] ................................. n_estimators=161, total= 1.5min
# [CV] n_estimators=181 ................................................
# [CV] ................................. n_estimators=181, total= 1.7min
# [CV] n_estimators=181 ................................................
# [CV] ................................. n_estimators=181, total= 1.7min
# [CV] n_estimators=201 ................................................
# [CV] ................................. n_estimators=181, total= 1.7min
# [CV] n_estimators=201 ................................................
# [CV] ................................. n_estimators=181, total= 1.7min
# [CV] n_estimators=201 ................................................
# [CV] ................................. n_estimators=181, total= 1.6min
# [CV] n_estimators=201 ................................................
# [CV] ................................. n_estimators=201, total= 1.9min
# [CV] n_estimators=201 ................................................
# [CV] ................................. n_estimators=201, total= 1.9min
# [CV] n_estimators=221 ................................................
# [CV] ................................. n_estimators=201, total= 2.0min
# [CV] n_estimators=221 ................................................
# [CV] ................................. n_estimators=201, total= 2.0min
# [CV] n_estimators=221 ................................................
# [CV] ................................. n_estimators=201, total= 2.0min
# [CV] n_estimators=221 ................................................
# [CV] ................................. n_estimators=221, total= 2.1min
# [CV] n_estimators=221 ................................................
# [CV] ................................. n_estimators=221, total= 2.1min
# [CV] n_estimators=241 ................................................
# [CV] ................................. n_estimators=221, total= 2.0min
# [CV] n_estimators=241 ................................................
# [CV] ................................. n_estimators=221, total= 2.0min
# [CV] n_estimators=241 ................................................
# [CV] ................................. n_estimators=221, total= 2.0min
# [CV] n_estimators=241 ................................................
# [CV] ................................. n_estimators=241, total= 2.2min
# [CV] n_estimators=241 ................................................
# [CV] ................................. n_estimators=241, total= 2.2min
# [CV] n_estimators=261 ................................................
# [CV] ................................. n_estimators=241, total= 2.2min
# [CV] n_estimators=261 ................................................
# [CV] ................................. n_estimators=241, total= 2.2min
# [CV] n_estimators=261 ................................................
# [CV] ................................. n_estimators=241, total= 2.3min
# [CV] n_estimators=261 ................................................
# [CV] ................................. n_estimators=261, total= 2.5min
# [CV] n_estimators=261 ................................................
# [CV] ................................. n_estimators=261, total= 2.4min
# [CV] n_estimators=281 ................................................
# [CV] ................................. n_estimators=261, total= 2.4min
# [CV] n_estimators=281 ................................................
# [CV] ................................. n_estimators=261, total= 2.4min
# [CV] n_estimators=281 ................................................
# [CV] ................................. n_estimators=261, total= 2.4min
# [CV] n_estimators=281 ................................................
# [CV] ................................. n_estimators=281, total= 2.6min
# [CV] n_estimators=281 ................................................
# [CV] ................................. n_estimators=281, total= 2.6min
# [CV] n_estimators=301 ................................................
# [CV] ................................. n_estimators=281, total= 2.6min
# [CV] n_estimators=301 ................................................
# [CV] ................................. n_estimators=281, total= 2.6min
# [CV] n_estimators=301 ................................................
# [CV] ................................. n_estimators=281, total= 2.6min
# [CV] n_estimators=301 ................................................
# [CV] ................................. n_estimators=301, total= 2.8min
# [CV] n_estimators=301 ................................................
# [CV] ................................. n_estimators=301, total= 2.7min
# [CV] n_estimators=321 ................................................
# [CV] ................................. n_estimators=301, total= 2.7min
# [CV] n_estimators=321 ................................................
# [CV] ................................. n_estimators=301, total= 3.0min
# [CV] n_estimators=321 ................................................
# [CV] ................................. n_estimators=301, total= 3.1min
# [CV] n_estimators=321 ................................................
# [CV] ................................. n_estimators=321, total= 3.5min
# [CV] n_estimators=321 ................................................
# [CV] ................................. n_estimators=321, total= 3.5min
# [CV] n_estimators=341 ................................................
# [CV] ................................. n_estimators=321, total= 3.4min
# [CV] n_estimators=341 ................................................
# [CV] ................................. n_estimators=321, total= 3.1min
# [CV] n_estimators=341 ................................................
# [CV] ................................. n_estimators=321, total= 3.0min
# [CV] n_estimators=341 ................................................
# [CV] ................................. n_estimators=341, total= 3.1min
# [CV] n_estimators=341 ................................................
# [CV] ................................. n_estimators=341, total= 3.2min
# [CV] n_estimators=361 ................................................
# [CV] ................................. n_estimators=341, total= 3.1min
# [CV] n_estimators=361 ................................................
# [CV] ................................. n_estimators=341, total= 3.1min
# [CV] n_estimators=361 ................................................
# [CV] ................................. n_estimators=341, total= 3.2min
# [CV] n_estimators=361 ................................................
# [CV] ................................. n_estimators=361, total= 3.3min
# [CV] n_estimators=361 ................................................
# [CV] ................................. n_estimators=361, total= 3.3min
# [CV] n_estimators=381 ................................................
# [CV] ................................. n_estimators=361, total= 3.3min
# [CV] n_estimators=381 ................................................
# [CV] ................................. n_estimators=361, total= 3.3min
# [CV] n_estimators=381 ................................................
# [CV] ................................. n_estimators=361, total= 3.3min
# [CV] n_estimators=381 ................................................
# [CV] ................................. n_estimators=381, total= 3.5min
# [CV] n_estimators=381 ................................................
# [CV] ................................. n_estimators=381, total= 3.5min
# [CV] n_estimators=401 ................................................
# [CV] ................................. n_estimators=381, total= 3.7min
# [CV] n_estimators=401 ................................................
# [CV] ................................. n_estimators=381, total= 3.9min
# [CV] n_estimators=401 ................................................
# [CV] ................................. n_estimators=381, total= 4.1min
# [CV] n_estimators=401 ................................................
# [CV] ................................. n_estimators=401, total= 4.4min
# [CV] n_estimators=401 ................................................
# [CV] ................................. n_estimators=401, total= 4.5min
# [CV] n_estimators=421 ................................................
# [CV] ................................. n_estimators=401, total= 4.5min
# [CV] n_estimators=421 ................................................
# [CV] ................................. n_estimators=401, total= 4.4min
# [CV] n_estimators=421 ................................................
# [CV] ................................. n_estimators=401, total= 4.4min
# [CV] n_estimators=421 ................................................
# [CV] ................................. n_estimators=421, total= 4.6min
# [CV] n_estimators=421 ................................................
# [CV] ................................. n_estimators=421, total= 4.8min
# [CV] n_estimators=441 ................................................
# [CV] ................................. n_estimators=421, total= 4.7min
# [CV] n_estimators=441 ................................................
# [CV] ................................. n_estimators=421, total= 4.7min
# [CV] n_estimators=441 ................................................
# [CV] ................................. n_estimators=421, total= 4.7min
# [CV] n_estimators=441 ................................................
# [CV] ................................. n_estimators=441, total= 4.9min
# [CV] n_estimators=441 ................................................
# [CV] ................................. n_estimators=441, total= 5.0min
# [CV] n_estimators=461 ................................................
# [CV] ................................. n_estimators=441, total= 4.9min
# [CV] n_estimators=461 ................................................
# [CV] ................................. n_estimators=441, total= 4.7min
# [CV] n_estimators=461 ................................................
# [CV] ................................. n_estimators=441, total= 4.8min
# [CV] n_estimators=461 ................................................
# [CV] ................................. n_estimators=461, total= 5.2min
# [CV] n_estimators=461 ................................................
# [CV] ................................. n_estimators=461, total= 5.2min
# [CV] n_estimators=481 ................................................
# [CV] ................................. n_estimators=461, total= 5.1min
# [CV] n_estimators=481 ................................................
# [CV] ................................. n_estimators=461, total= 5.0min
# [CV] n_estimators=481 ................................................
# [CV] ................................. n_estimators=461, total= 5.1min
# [CV] n_estimators=481 ................................................
# [CV] ................................. n_estimators=481, total= 5.3min
# [CV] n_estimators=481 ................................................
# [CV] ................................. n_estimators=481, total= 5.3min
# [CV] ................................. n_estimators=481, total= 4.9min
# [CV] ................................. n_estimators=481, total= 4.3min
# [CV] ................................. n_estimators=481, total= 3.6min
# [Parallel(n_jobs=4)]: Done 125 out of 125 | elapsed: 77.1min finished
# GridSearchCV(cv=5, error_score='raise',
#        estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=42, verbose=0, warm_start=False),
#        fit_params=None, iid=True, n_jobs=4,
#        param_grid={'n_estimators': range(1, 500, 20)},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=2)

# %%
print("Best n_estimators: ", rand_forest_cv.best_params_['n_estimators'])
print("Test set RMSE: ", mean_squared_error(y_test, rand_forest_cv.predict(x_test)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-32ec6d976f7d> in <module>()
# ----> 1 print("Best n_estimators: ", rand_forest_cv.best_parameters_['n_estimators'])
#       2 print("Test set RMSE: ", mean_squared_error(y_test, rand_forest_cv.predict(x_test)))
#
# NameError: name 'rand_forest_cv' is not defined

# %% [markdown]
# ### Part b

# %%
params = {
    'n_estimators': range(1,500,50),
    'learning_rate': 10.0 ** np.array(range(-3,0,1), dtype=float),
    'max_depth': range(1,5)
}
gbr_cv = GridSearchCV(GradientBoostingRegressor(random_state=42), params, cv=5, verbose=2, n_jobs=-1)
gbr_cv.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 120 candidates, totalling 600 fits
# [CV] max_depth=1, learning_rate=0.001, n_estimators=1 ................
# [CV] max_depth=1, learning_rate=0.001, n_estimators=1 ................
# [CV] max_depth=1, learning_rate=0.001, n_estimators=1 ................
# [CV] max_depth=1, learning_rate=0.001, n_estimators=1 ................
# [CV] . max_depth=1, learning_rate=0.001, n_estimators=1, total=   0.1s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=1 ................
# [CV] . max_depth=1, learning_rate=0.001, n_estimators=1, total=   0.1s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=51 ...............
# [CV] . max_depth=1, learning_rate=0.001, n_estimators=1, total=   0.1s
# [CV] . max_depth=1, learning_rate=0.001, n_estimators=1, total=   0.1s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=51 ...............
# [CV] max_depth=1, learning_rate=0.001, n_estimators=51 ...............
# [CV] . max_depth=1, learning_rate=0.001, n_estimators=1, total=   0.1s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=51 ...............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=51, total=   0.3s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=51 ...............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=51, total=   0.2s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=101 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=51, total=   0.4s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=101 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=51, total=   0.4s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=101 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=51, total=   0.3s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=101 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=101, total=   0.5s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=101 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=101, total=   0.5s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=151 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=101, total=   0.5s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=151 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=101, total=   0.6s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=151 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=101, total=   0.6s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=151 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=151, total=   0.8s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=151 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=151, total=   0.9s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=201 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=151, total=   0.8s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=201 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=151, total=   1.0s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=201 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=151, total=   0.8s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=201 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=201, total=   1.3s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=201 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=201, total=   1.1s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=251 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=201, total=   1.2s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=251 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=201, total=   1.2s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=251 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=201, total=   1.3s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=251 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=251, total=   1.4s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=251 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=251, total=   1.4s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=301 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=251, total=   1.4s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=301 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=251, total=   1.5s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=301 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=251, total=   1.4s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=301 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=301, total=   1.8s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=301 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=301, total=   1.8s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=351 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=301, total=   1.9s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=351 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=301, total=   1.8s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=351 ..............
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:    8.5s
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=301, total=   1.8s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=351 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=351, total=   2.0s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=351 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=351, total=   2.0s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=401 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=351, total=   2.2s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=401 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=351, total=   2.1s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=401 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=351, total=   2.1s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=401 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=401, total=   2.4s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=401 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=401, total=   2.3s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=451 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=401, total=   2.4s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=451 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=401, total=   2.4s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=451 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=401, total=   2.5s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=451 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=451, total=   2.7s
# [CV] max_depth=1, learning_rate=0.001, n_estimators=451 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=451, total=   2.8s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=1 ................
# [CV] . max_depth=2, learning_rate=0.001, n_estimators=1, total=   0.1s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=1 ................
# [CV] . max_depth=2, learning_rate=0.001, n_estimators=1, total=   0.0s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=1 ................
# [CV] . max_depth=2, learning_rate=0.001, n_estimators=1, total=   0.1s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=1 ................
# [CV] . max_depth=2, learning_rate=0.001, n_estimators=1, total=   0.0s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=1 ................
# [CV] . max_depth=2, learning_rate=0.001, n_estimators=1, total=   0.1s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=51 ...............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=451, total=   2.9s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=51 ...............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=51, total=   0.9s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=51 ...............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=51, total=   0.7s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=51 ...............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=51, total=   0.7s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=51 ...............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=451, total=   3.0s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=101 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=51, total=   0.8s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=101 ..............
# [CV]  max_depth=1, learning_rate=0.001, n_estimators=451, total=   3.0s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=101 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=51, total=   0.7s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=101 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=101, total=   1.4s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=101 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=101, total=   1.6s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=151 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=101, total=   1.4s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=151 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=101, total=   1.6s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=151 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=101, total=   1.4s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=151 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=151, total=   2.0s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=151 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=151, total=   2.2s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=201 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=151, total=   2.0s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=201 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=151, total=   2.2s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=201 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=151, total=   2.1s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=201 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=201, total=   3.1s
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=201, total=   2.8s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=201 ..............
# [CV] max_depth=2, learning_rate=0.001, n_estimators=251 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=201, total=   2.8s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=251 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=201, total=   3.0s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=251 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=201, total=   2.8s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=251 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=251, total=   3.6s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=251 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=251, total=   3.2s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=301 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=251, total=   3.9s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=301 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=251, total=   3.8s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=301 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=251, total=   3.4s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=301 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=301, total=   4.7s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=301 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=301, total=   3.8s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=351 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=301, total=   4.4s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=351 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=301, total=   4.6s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=351 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=301, total=   4.5s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=351 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=351, total=   4.9s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=351 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=351, total=   4.9s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=401 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=351, total=   5.3s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=401 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=351, total=   5.6s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=401 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=351, total=   4.8s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=401 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=401, total=   5.8s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=401 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=401, total=   5.4s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=451 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=401, total=   5.8s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=451 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=401, total=   6.0s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=451 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=401, total=   5.9s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=451 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=451, total=   6.3s
# [CV] max_depth=2, learning_rate=0.001, n_estimators=451 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=451, total=   6.1s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=1 ................
# [CV] . max_depth=3, learning_rate=0.001, n_estimators=1, total=   0.1s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=1 ................
# [CV] . max_depth=3, learning_rate=0.001, n_estimators=1, total=   0.1s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=1 ................
# [CV] . max_depth=3, learning_rate=0.001, n_estimators=1, total=   0.1s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=1 ................
# [CV] . max_depth=3, learning_rate=0.001, n_estimators=1, total=   0.1s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=1 ................
# [CV] . max_depth=3, learning_rate=0.001, n_estimators=1, total=   0.1s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=51 ...............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=451, total=   6.9s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=51 ...............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=51, total=   1.6s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=51 ...............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=51, total=   1.2s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=51 ...............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=51, total=   1.3s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=51 ...............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=451, total=   7.1s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=101 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=51, total=   1.5s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=101 ..............
# [CV]  max_depth=2, learning_rate=0.001, n_estimators=451, total=   6.4s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=101 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=51, total=   1.4s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=101 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=101, total=   2.5s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=101 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=101, total=   2.5s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=151 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=101, total=   3.0s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=151 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=101, total=   2.9s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=151 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=101, total=   2.7s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=151 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=151, total=   4.0s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=151 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=151, total=   4.5s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=201 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=151, total=   4.1s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=201 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=151, total=   4.4s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=201 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=151, total=   3.9s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=201 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=201, total=   5.5s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=201 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=201, total=   5.1s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=251 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=201, total=   4.9s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=251 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=201, total=   5.2s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=251 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=201, total=   4.9s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=251 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=251, total=   6.9s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=251 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=251, total=   6.3s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=301 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=251, total=   6.4s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=301 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=251, total=   6.6s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=301 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=251, total=   6.3s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=301 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=301, total=   7.9s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=301 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=301, total=   7.3s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=351 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=301, total=   7.7s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=351 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=301, total=   7.5s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=351 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=301, total=   7.4s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=351 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=351, total=   9.2s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=351 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=351, total=   8.6s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=401 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=351, total=   8.6s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=401 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=351, total=   8.8s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=401 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=351, total=   8.1s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=401 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=401, total=   9.5s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=401 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=401, total=   9.0s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=451 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=401, total=   9.6s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=451 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=401, total=   9.8s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=451 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=401, total=   9.7s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=451 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=451, total=  11.5s
# [CV] max_depth=3, learning_rate=0.001, n_estimators=451 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=451, total=  10.9s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=1 ................
# [CV] . max_depth=4, learning_rate=0.001, n_estimators=1, total=   0.1s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=1 ................
# [CV] . max_depth=4, learning_rate=0.001, n_estimators=1, total=   0.1s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=1 ................
# [CV] . max_depth=4, learning_rate=0.001, n_estimators=1, total=   0.1s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=1 ................
# [CV] . max_depth=4, learning_rate=0.001, n_estimators=1, total=   0.1s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=1 ................
# [CV] . max_depth=4, learning_rate=0.001, n_estimators=1, total=   0.1s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=51 ...............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=51, total=   2.6s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=51 ...............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=451, total=  11.7s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=51 ...............
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:  2.2min
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=51, total=   2.1s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=51 ...............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=51, total=   2.1s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=51 ...............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=451, total=  11.9s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=101 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=51, total=   2.3s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=101 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=51, total=   2.6s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=101 ..............
# [CV]  max_depth=3, learning_rate=0.001, n_estimators=451, total=  11.5s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=101 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=101, total=   5.0s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=101 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=101, total=   4.4s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=151 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=101, total=   4.3s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=151 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=101, total=   4.5s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=151 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=101, total=   4.0s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=151 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=151, total=   6.2s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=151 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=151, total=   6.9s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=201 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=151, total=   6.3s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=201 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=151, total=   6.9s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=201 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=151, total=   6.7s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=201 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=201, total=   8.8s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=201 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=201, total=   9.8s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=251 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=201, total=   8.4s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=251 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=201, total=   8.2s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=251 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=201, total=   8.2s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=251 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=251, total=  11.3s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=251 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=251, total=  10.1s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=301 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=251, total=  10.8s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=301 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=251, total=  10.5s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=301 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=251, total=   9.9s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=301 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=301, total=  13.1s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=301 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=301, total=  12.2s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=351 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=301, total=  12.1s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=351 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=301, total=  12.5s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=351 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=301, total=  11.4s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=351 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=351, total=  14.6s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=351 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=351, total=  14.0s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=401 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=351, total=  14.3s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=401 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=351, total=  14.3s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=401 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=351, total=  13.3s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=401 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=401, total=  16.2s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=401 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=401, total=  15.5s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=451 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=401, total=  16.2s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=451 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=401, total=  15.6s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=451 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=401, total=  15.5s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=451 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=451, total=  19.0s
# [CV] max_depth=4, learning_rate=0.001, n_estimators=451 ..............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=451, total=  17.8s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=1 .................
# [CV] .. max_depth=1, learning_rate=0.01, n_estimators=1, total=   0.1s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=1 .................
# [CV] .. max_depth=1, learning_rate=0.01, n_estimators=1, total=   0.0s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=1 .................
# [CV] .. max_depth=1, learning_rate=0.01, n_estimators=1, total=   0.1s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=1 .................
# [CV] .. max_depth=1, learning_rate=0.01, n_estimators=1, total=   0.0s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=1 .................
# [CV] .. max_depth=1, learning_rate=0.01, n_estimators=1, total=   0.0s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=51 ................
# [CV] . max_depth=1, learning_rate=0.01, n_estimators=51, total=   0.3s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=51 ................
# [CV] . max_depth=1, learning_rate=0.01, n_estimators=51, total=   0.4s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=51 ................
# [CV] . max_depth=1, learning_rate=0.01, n_estimators=51, total=   0.4s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=51 ................
# [CV] . max_depth=1, learning_rate=0.01, n_estimators=51, total=   0.4s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=51 ................
# [CV] . max_depth=1, learning_rate=0.01, n_estimators=51, total=   0.3s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=101 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=101, total=   0.6s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=101 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=101, total=   0.6s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=101 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=101, total=   0.5s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=101 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=101, total=   0.6s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=101 ...............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=451, total=  18.3s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=151 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=101, total=   0.7s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=151 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=151, total=   0.9s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=151 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=151, total=   1.0s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=151 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=151, total=   1.0s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=151 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=151, total=   1.0s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=201 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=151, total=   0.9s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=201 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=201, total=   1.2s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=201 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=201, total=   1.2s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=201 ...............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=451, total=  17.8s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=201 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=201, total=   1.3s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=251 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=201, total=   1.2s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=251 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=201, total=   1.4s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=251 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=251, total=   1.7s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=251 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=251, total=   1.7s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=251 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=251, total=   1.5s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=301 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=251, total=   1.4s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=301 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=251, total=   1.6s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=301 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=301, total=   1.7s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=301 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=301, total=   1.7s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=301 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=301, total=   2.1s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=351 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=301, total=   1.9s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=351 ...............
# [CV]  max_depth=4, learning_rate=0.001, n_estimators=451, total=  18.0s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=351 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=301, total=   2.0s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=351 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=351, total=   2.4s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=351 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=351, total=   2.4s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=401 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=351, total=   2.3s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=401 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=351, total=   2.1s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=401 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=351, total=   2.4s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=401 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=401, total=   2.5s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=401 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=401, total=   2.6s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=451 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=401, total=   2.5s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=451 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=401, total=   2.6s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=451 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=401, total=   2.7s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=451 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=451, total=   3.0s
# [CV] max_depth=1, learning_rate=0.01, n_estimators=451 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=451, total=   2.7s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=1 .................
# [CV] .. max_depth=2, learning_rate=0.01, n_estimators=1, total=   0.1s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=1 .................
# [CV] .. max_depth=2, learning_rate=0.01, n_estimators=1, total=   0.1s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=1 .................
# [CV] .. max_depth=2, learning_rate=0.01, n_estimators=1, total=   0.1s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=1 .................
# [CV] .. max_depth=2, learning_rate=0.01, n_estimators=1, total=   0.1s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=1 .................
# [CV] .. max_depth=2, learning_rate=0.01, n_estimators=1, total=   0.1s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=51 ................
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=451, total=   2.9s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=51 ................
# [CV] . max_depth=2, learning_rate=0.01, n_estimators=51, total=   0.8s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=51 ................
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=451, total=   2.9s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=51 ................
# [CV] . max_depth=2, learning_rate=0.01, n_estimators=51, total=   0.7s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=51 ................
# [CV] . max_depth=2, learning_rate=0.01, n_estimators=51, total=   0.9s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=101 ...............
# [CV]  max_depth=1, learning_rate=0.01, n_estimators=451, total=   3.1s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=101 ...............
# [CV] . max_depth=2, learning_rate=0.01, n_estimators=51, total=   0.8s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=101 ...............
# [CV] . max_depth=2, learning_rate=0.01, n_estimators=51, total=   0.8s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=101 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=101, total=   1.5s
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=101, total=   1.7s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=101 ...............
# [CV] max_depth=2, learning_rate=0.01, n_estimators=151 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=101, total=   1.6s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=151 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=101, total=   1.5s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=151 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=101, total=   1.6s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=151 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=151, total=   2.5s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=151 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=151, total=   2.5s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=201 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=151, total=   2.4s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=201 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=151, total=   2.4s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=201 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=151, total=   2.3s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=201 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=201, total=   3.1s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=201 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=201, total=   3.2s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=251 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=201, total=   3.3s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=251 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=201, total=   3.2s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=251 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=201, total=   3.2s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=251 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=251, total=   4.1s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=251 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=251, total=   3.7s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=301 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=251, total=   3.8s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=301 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=251, total=   3.5s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=301 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=251, total=   4.1s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=301 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=301, total=   4.4s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=301 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=301, total=   4.4s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=351 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=301, total=   4.5s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=351 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=301, total=   4.7s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=351 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=301, total=   4.5s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=351 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=351, total=   4.9s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=351 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=351, total=   5.2s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=401 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=351, total=   5.5s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=401 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=351, total=   5.3s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=401 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=351, total=   5.0s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=401 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=401, total=   5.6s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=401 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=401, total=   5.5s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=451 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=401, total=   5.6s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=451 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=401, total=   5.6s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=451 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=401, total=   6.2s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=451 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=451, total=   6.2s
# [CV] max_depth=2, learning_rate=0.01, n_estimators=451 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=451, total=   6.5s
# [CV] max_depth=3, learning_rate=0.01, n_estimators=1 .................
# [CV] .. max_depth=3, learning_rate=0.01, n_estimators=1, total=   0.1s
# [CV] max_depth=3, learning_rate=0.01, n_estimators=1 .................
# [CV] .. max_depth=3, learning_rate=0.01, n_estimators=1, total=   0.1s
# [CV] max_depth=3, learning_rate=0.01, n_estimators=1 .................
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=451, total=   6.0s
# [CV] max_depth=3, learning_rate=0.01, n_estimators=1 .................
# [CV] .. max_depth=3, learning_rate=0.01, n_estimators=1, total=   0.1s
# [CV] max_depth=3, learning_rate=0.01, n_estimators=1 .................
# [CV] .. max_depth=3, learning_rate=0.01, n_estimators=1, total=   0.1s
# [CV] max_depth=3, learning_rate=0.01, n_estimators=51 ................
# [CV] .. max_depth=3, learning_rate=0.01, n_estimators=1, total=   0.1s
# [CV] max_depth=3, learning_rate=0.01, n_estimators=51 ................
# [CV] . max_depth=3, learning_rate=0.01, n_estimators=51, total=   1.4s
# [CV] . max_depth=3, learning_rate=0.01, n_estimators=51, total=   1.3s
# [CV] max_depth=3, learning_rate=0.01, n_estimators=51 ................
# [CV] max_depth=3, learning_rate=0.01, n_estimators=51 ................
# [CV] . max_depth=3, learning_rate=0.01, n_estimators=51, total=   1.3s
# [CV] max_depth=3, learning_rate=0.01, n_estimators=51 ................
# [CV] . max_depth=3, learning_rate=0.01, n_estimators=51, total=   1.4s
# [CV] max_depth=3, learning_rate=0.01, n_estimators=101 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=451, total=   6.5s
# [CV] max_depth=3, learning_rate=0.01, n_estimators=101 ...............
# [CV] . max_depth=3, learning_rate=0.01, n_estimators=51, total=   1.3s
# [CV] max_depth=3, learning_rate=0.01, n_estimators=101 ...............
# [CV]  max_depth=2, learning_rate=0.01, n_estimators=451, total=   6.8s
# [CV] max_depth=3, learning_rate=0.01, n_estimators=101 ...............
# [CV]  max_depth=3, learning_rate=0.01, n_estimators=101, total=   2.6s
# [CV] max_depth=3, learning_rate=0.01, n_estimators=101 ...............
# [CV]  max_depth=3, learning_rate=0.01, n_estimators=101, total=   2.7s
# [CV] max_depth=3, learning_rate=0.01, n_estimators=151 ...............
# [CV]  max_depth=3, learning_rate=0.01, n_estimators=101, total=   2.4s
# [CV] max_depth=3, learning_rate=0.01, n_estimators=151 ...............
# [CV]  max_depth=3, learning_rate=0.01, n_estimators=101, total=   2.6s
# [CV] max_depth=3, learning_rate=0.01, n_estimators=151 ...............
# [CV]  max_depth=3, learning_rate=0.01, n_estimators=101, total=   2.6s
# [CV] max_depth=3, learning_rate=0.01, n_estimators=151 ...............
# [CV]  max_depth=3, learning_rate=0.01, n_estimators=151, total=   4.0s
# [CV] max_depth=3, learning_rate=0.01, n_estimators=151 ...............
# [CV]  max_depth=3, learning_rate=0.01, n_estimators=151, total=   3.8s
# [CV] max_depth=3, learning_rate=0.01, n_estimators=201 ...............
# [CV]  max_depth=3, learning_rate=0.01, n_estimators=151, total=   4.2s
# [CV] max_depth=3, learning_rate=0.01, n_estimators=201 ...............
# [CV]  max_depth=3, learning_rate=0.01, n_estimators=151, total=   4.1s
# [CV] max_depth=3, learning_rate=0.01, n_estimators=201 ...............
# [CV]  max_depth=3, learning_rate=0.01, n_estimators=151, total=   4.3s
# [CV] max_depth=3, learning_rate=0.01, n_estimators=201 ...............
# [CV]  max_depth=3, learning_rate=0.01, n_estimators=201, total=   5.3s
# [CV] max_depth=3, learning_rate=0.01, n_estimators=201 ...............
# [CV]  max_depth=3, learning_rate=0.01, n_estimators=201, total=   4.9s
# [CV] max_depth=3, learning_rate=0.01, n_estimators=251 ...............
# [CV]  max_depth=3, learning_rate=0.01, n_estimators=201, total=   5.5s
# [CV] max_depth=3, learning_rate=0.01, n_estimators=251 ...............
# [CV]  max_depth=3, learning_rate=0.01, n_estimators=201, total=   5.3s
# [CV] max_depth=3, learning_rate=0.01, n_estimators=251 ...............
# [CV]  max_depth=3, learning_rate=0.01, n_estimators=201, total=   5.3s
# [CV] max_depth=3, learning_rate=0.01, n_estimators=251 ...............
# [CV]  max_depth=3, learning_rate=0.01, n_estimators=251, total=   6.4s
# [CV] max_depth=3, learning_rate=0.01, n_estimators=251 ...............
# [CV]  max_depth=3, learning_rate=0.01, n_estimators=251, total=   6.4s
# [CV] max_depth=3, learning_rate=0.01, n_estimators=301 ...............
# [CV]  max_depth=3, learning_rate=0.01, n_estimators=251, total=   6.4s
# [CV] max_depth=3, learning_rate=0.01, n_estimators=301 ...............
# [CV]  max_depth=3, learning_rate=0.01, n_estimators=251, total=   6.6s
# [CV] max_depth=3, learning_rate=0.01, n_estimators=301 ...............
# [CV]  max_depth=3, learning_rate=0.01, n_estimators=251, total=   6.2s
# [CV] max_depth=3, learning_rate=0.01, n_estimators=301 ...............
# [CV]  max_depth=3, learning_rate=0.01, n_estimators=301, total=   7.5s
# [CV] max_depth=3, learning_rate=0.01, n_estimators=301 ...............
# [CV]  max_depth=3, learning_rate=0.01, n_estimators=301, total=   7.8s
# [CV] max_depth=3, learning_rate=0.01, n_estimators=351 ...............
# [CV]  max_depth=3, learning_rate=0.01, n_estimators=301, total=   7.4s
# [CV] max_depth=3, learning_rate=0.01, n_estimators=351 ...............
# [CV]  max_depth=3, learning_rate=0.01, n_estimators=301, total=   7.4s
# ...
# [CV] max_depth=2, learning_rate=0.1, n_estimators=451 ................
# [CV] . max_depth=2, learning_rate=0.1, n_estimators=401, total=   5.3s
# [CV] max_depth=2, learning_rate=0.1, n_estimators=451 ................
# [CV] . max_depth=2, learning_rate=0.1, n_estimators=401, total=   5.5s
# [CV] max_depth=2, learning_rate=0.1, n_estimators=451 ................
# [CV] . max_depth=2, learning_rate=0.1, n_estimators=401, total=   5.4s
# [CV] max_depth=2, learning_rate=0.1, n_estimators=451 ................
# [CV] . max_depth=2, learning_rate=0.1, n_estimators=451, total=   6.1s
# [CV] max_depth=2, learning_rate=0.1, n_estimators=451 ................
# [CV] . max_depth=2, learning_rate=0.1, n_estimators=451, total=   6.3s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=1 ..................
# [CV] ... max_depth=3, learning_rate=0.1, n_estimators=1, total=   0.1s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=1 ..................
# [CV] ... max_depth=3, learning_rate=0.1, n_estimators=1, total=   0.0s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=1 ..................
# [CV] ... max_depth=3, learning_rate=0.1, n_estimators=1, total=   0.1s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=1 ..................
# [CV] ... max_depth=3, learning_rate=0.1, n_estimators=1, total=   0.1s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=1 ..................
# [CV] ... max_depth=3, learning_rate=0.1, n_estimators=1, total=   0.1s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=51 .................
# [CV] . max_depth=2, learning_rate=0.1, n_estimators=451, total=   6.7s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=51 .................
# [CV] .. max_depth=3, learning_rate=0.1, n_estimators=51, total=   1.3s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=51 .................
# [CV] .. max_depth=3, learning_rate=0.1, n_estimators=51, total=   1.2s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=51 .................
# [CV] . max_depth=2, learning_rate=0.1, n_estimators=451, total=   6.5s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=51 .................
# [CV] .. max_depth=3, learning_rate=0.1, n_estimators=51, total=   1.2s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=101 ................
# [CV] .. max_depth=3, learning_rate=0.1, n_estimators=51, total=   1.3s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=101 ................
# [CV] .. max_depth=3, learning_rate=0.1, n_estimators=51, total=   1.2s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=101 ................
# [CV] . max_depth=2, learning_rate=0.1, n_estimators=451, total=   6.4s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=101 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=101, total=   2.4s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=101 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=101, total=   2.4s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=151 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=101, total=   2.5s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=151 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=101, total=   2.6s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=151 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=101, total=   2.4s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=151 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=151, total=   3.6s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=151 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=151, total=   3.7s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=201 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=151, total=   3.7s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=201 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=151, total=   3.8s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=201 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=151, total=   3.7s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=201 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=201, total=   4.8s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=201 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=201, total=   4.6s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=251 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=201, total=   4.6s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=251 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=201, total=   4.8s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=251 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=201, total=   4.8s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=251 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=251, total=   6.2s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=251 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=251, total=   5.8s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=301 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=251, total=   5.8s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=301 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=251, total=   5.9s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=301 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=251, total=   5.8s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=301 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=301, total=   7.0s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=301 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=301, total=   6.7s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=351 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=301, total=   7.0s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=351 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=301, total=   7.0s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=351 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=301, total=   6.8s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=351 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=351, total=   8.2s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=351 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=351, total=   7.7s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=401 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=351, total=   8.0s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=401 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=351, total=   8.0s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=401 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=351, total=   7.7s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=401 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=401, total=   9.5s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=401 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=401, total=   9.6s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=451 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=401, total=   9.9s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=451 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=401, total=   9.6s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=451 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=401, total=  10.8s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=451 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=451, total=  11.2s
# [CV] max_depth=3, learning_rate=0.1, n_estimators=451 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=451, total=  11.6s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=1 ..................
# [CV] ... max_depth=4, learning_rate=0.1, n_estimators=1, total=   0.1s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=1 ..................
# [CV] ... max_depth=4, learning_rate=0.1, n_estimators=1, total=   0.1s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=1 ..................
# [CV] ... max_depth=4, learning_rate=0.1, n_estimators=1, total=   0.1s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=1 ..................
# [CV] ... max_depth=4, learning_rate=0.1, n_estimators=1, total=   0.1s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=1 ..................
# [CV] ... max_depth=4, learning_rate=0.1, n_estimators=1, total=   0.1s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=51 .................
# [CV] .. max_depth=4, learning_rate=0.1, n_estimators=51, total=   1.9s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=51 .................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=451, total=  11.3s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=51 .................
# [CV] .. max_depth=4, learning_rate=0.1, n_estimators=51, total=   2.0s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=51 .................
# [CV] .. max_depth=4, learning_rate=0.1, n_estimators=51, total=   2.1s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=51 .................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=451, total=  10.8s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=101 ................
# [CV] .. max_depth=4, learning_rate=0.1, n_estimators=51, total=   1.9s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=101 ................
# [CV] .. max_depth=4, learning_rate=0.1, n_estimators=51, total=   1.9s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=101 ................
# [CV] . max_depth=3, learning_rate=0.1, n_estimators=451, total=  10.9s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=101 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=101, total=   3.4s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=101 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=101, total=   3.5s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=151 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=101, total=   3.5s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=151 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=101, total=   3.8s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=151 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=101, total=   3.6s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=151 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=151, total=   4.8s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=151 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=151, total=   5.0s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=201 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=151, total=   5.0s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=201 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=151, total=   5.0s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=201 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=151, total=   5.2s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=201 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=201, total=   7.1s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=201 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=201, total=   6.9s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=251 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=201, total=   7.3s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=251 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=201, total=   7.3s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=251 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=201, total=   7.2s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=251 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=251, total=   9.1s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=251 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=251, total=   9.1s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=301 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=251, total=   9.0s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=301 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=251, total=   8.6s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=301 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=251, total=   8.4s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=301 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=301, total=  10.5s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=301 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=301, total=  10.1s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=351 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=301, total=  10.5s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=351 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=301, total=  10.2s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=351 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=301, total=  10.0s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=351 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=351, total=  11.8s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=351 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=351, total=  11.9s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=401 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=351, total=  11.8s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=401 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=351, total=  12.1s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=401 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=351, total=  11.9s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=401 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=401, total=  14.9s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=401 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=401, total=  14.5s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=451 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=401, total=  14.6s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=451 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=401, total=  14.6s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=451 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=401, total=  13.6s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=451 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=451, total=  16.0s
# [CV] max_depth=4, learning_rate=0.1, n_estimators=451 ................
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=451, total=  15.2s
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=451, total=  16.4s
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=451, total=  14.9s
# [CV] . max_depth=4, learning_rate=0.1, n_estimators=451, total=  13.5s
# [Parallel(n_jobs=-1)]: Done 600 out of 600 | elapsed: 12.1min finished
# GridSearchCV(cv=5, error_score='raise',
#        estimator=GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.1, loss='ls', max_depth=3, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=100, presort='auto', random_state=42,
#              subsample=1.0, verbose=0, warm_start=False),
#        fit_params=None, iid=True, n_jobs=-1,
#        param_grid={'max_depth': range(1, 5), 'learning_rate': array([0.001, 0.01 , 0.1  ]), 'n_estimators': range(1, 500, 50)},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=2)

# %%
import math
print("Best estimators: ", gbr_cv.best_params_)
print("Test set RMSE: ", math.sqrt(mean_squared_error(y_test, gbr_cv.predict(x_test))))
# Out:
# Best estimators:  {'max_depth': 4, 'learning_rate': 0.1, 'n_estimators': 451}
# Test set RMSE:  76.53596367343135

# %% [markdown]
# ### Part c

# %%
params = {
    'n_estimators': range(1,16,2),
    'learning_rate': 10.0 ** np.array(range(-3,0,1), dtype=float),
}
ada_cv = GridSearchCV(AdaBoostRegressor(random_state=42), params, cv=5, verbose=2, n_jobs=-1)
ada_cv.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV] learning_rate=0.001, n_estimators=1 .............................
# [CV] .............. learning_rate=0.001, n_estimators=1, total=   0.2s
# [CV] learning_rate=0.001, n_estimators=1 .............................
# [CV] .............. learning_rate=0.001, n_estimators=1, total=   0.1s
# [CV] learning_rate=0.001, n_estimators=1 .............................
# [CV] learning_rate=0.001, n_estimators=1 .............................
# [CV] learning_rate=0.001, n_estimators=1 .............................
# [CV] learning_rate=0.001, n_estimators=3 .............................
# [CV] .............. learning_rate=0.001, n_estimators=1, total=   0.1s
# [CV] learning_rate=0.001, n_estimators=3 .............................
# [CV] .............. learning_rate=0.001, n_estimators=1, total=   0.1s
# [CV] learning_rate=0.001, n_estimators=3 .............................
# [CV] .............. learning_rate=0.001, n_estimators=1, total=   0.2s
# [CV] learning_rate=0.001, n_estimators=3 .............................
# [CV] .............. learning_rate=0.001, n_estimators=3, total=   0.2s
# [CV] learning_rate=0.001, n_estimators=3 .............................
# [CV] .............. learning_rate=0.001, n_estimators=3, total=   0.3s
# [CV] learning_rate=0.001, n_estimators=5 .............................
# [CV] .............. learning_rate=0.001, n_estimators=3, total=   0.2s
# [CV] learning_rate=0.001, n_estimators=5 .............................
# [CV] .............. learning_rate=0.001, n_estimators=3, total=   0.3s
# [CV] learning_rate=0.001, n_estimators=5 .............................
# [CV] .............. learning_rate=0.001, n_estimators=3, total=   0.2s
# [CV] learning_rate=0.001, n_estimators=5 .............................
# [CV] .............. learning_rate=0.001, n_estimators=5, total=   0.3s
# [CV] learning_rate=0.001, n_estimators=5 .............................
# [CV] .............. learning_rate=0.001, n_estimators=5, total=   0.4s
# [CV] learning_rate=0.001, n_estimators=7 .............................
# [CV] .............. learning_rate=0.001, n_estimators=5, total=   0.3s
# [CV] learning_rate=0.001, n_estimators=7 .............................
# [CV] .............. learning_rate=0.001, n_estimators=5, total=   0.4s
# [CV] learning_rate=0.001, n_estimators=7 .............................
# [CV] .............. learning_rate=0.001, n_estimators=5, total=   0.3s
# [CV] learning_rate=0.001, n_estimators=7 .............................
# [CV] .............. learning_rate=0.001, n_estimators=7, total=   0.5s
# [CV] learning_rate=0.001, n_estimators=7 .............................
# [CV] .............. learning_rate=0.001, n_estimators=7, total=   0.4s
# [CV] learning_rate=0.001, n_estimators=9 .............................
# [CV] .............. learning_rate=0.001, n_estimators=7, total=   0.5s
# [CV] learning_rate=0.001, n_estimators=9 .............................
# [CV] .............. learning_rate=0.001, n_estimators=7, total=   0.6s
# [CV] learning_rate=0.001, n_estimators=9 .............................
# [CV] .............. learning_rate=0.001, n_estimators=7, total=   0.4s
# [CV] learning_rate=0.001, n_estimators=9 .............................
# [CV] .............. learning_rate=0.001, n_estimators=9, total=   0.6s
# [CV] learning_rate=0.001, n_estimators=9 .............................
# [CV] .............. learning_rate=0.001, n_estimators=9, total=   0.6s
# [CV] learning_rate=0.001, n_estimators=11 ............................
# [CV] .............. learning_rate=0.001, n_estimators=9, total=   0.6s
# [CV] learning_rate=0.001, n_estimators=11 ............................
# [CV] .............. learning_rate=0.001, n_estimators=9, total=   0.6s
# [CV] learning_rate=0.001, n_estimators=11 ............................
# [CV] .............. learning_rate=0.001, n_estimators=9, total=   0.6s
# [CV] learning_rate=0.001, n_estimators=11 ............................
# [CV] ............. learning_rate=0.001, n_estimators=11, total=   0.7s
# [CV] learning_rate=0.001, n_estimators=11 ............................
# [CV] ............. learning_rate=0.001, n_estimators=11, total=   0.7s
# [CV] learning_rate=0.001, n_estimators=13 ............................
# [CV] ............. learning_rate=0.001, n_estimators=11, total=   0.8s
# [CV] learning_rate=0.001, n_estimators=13 ............................
# [CV] ............. learning_rate=0.001, n_estimators=11, total=   0.7s
# [CV] learning_rate=0.001, n_estimators=13 ............................
# [CV] ............. learning_rate=0.001, n_estimators=11, total=   0.7s
# [CV] learning_rate=0.001, n_estimators=13 ............................
# [CV] ............. learning_rate=0.001, n_estimators=13, total=   0.7s
# [CV] learning_rate=0.001, n_estimators=13 ............................
# [CV] ............. learning_rate=0.001, n_estimators=13, total=   0.9s
# [CV] learning_rate=0.001, n_estimators=15 ............................
# [CV] ............. learning_rate=0.001, n_estimators=13, total=   0.8s
# [CV] learning_rate=0.001, n_estimators=15 ............................
# [CV] ............. learning_rate=0.001, n_estimators=13, total=   0.7s
# [CV] learning_rate=0.001, n_estimators=15 ............................
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:    4.7s
# [CV] ............. learning_rate=0.001, n_estimators=13, total=   0.8s
# [CV] learning_rate=0.001, n_estimators=15 ............................
# [CV] ............. learning_rate=0.001, n_estimators=15, total=   1.0s
# [CV] learning_rate=0.001, n_estimators=15 ............................
# [CV] ............. learning_rate=0.001, n_estimators=15, total=   1.1s
# [CV] learning_rate=0.01, n_estimators=1 ..............................
# [CV] ............. learning_rate=0.001, n_estimators=15, total=   1.0s
# [CV] learning_rate=0.01, n_estimators=1 ..............................
# [CV] ............... learning_rate=0.01, n_estimators=1, total=   0.1s
# [CV] learning_rate=0.01, n_estimators=1 ..............................
# [CV] ............... learning_rate=0.01, n_estimators=1, total=   0.1s
# [CV] learning_rate=0.01, n_estimators=1 ..............................
# [CV] ............... learning_rate=0.01, n_estimators=1, total=   0.1s
# [CV] learning_rate=0.01, n_estimators=1 ..............................
# [CV] ............... learning_rate=0.01, n_estimators=1, total=   0.1s
# [CV] learning_rate=0.01, n_estimators=3 ..............................
# [CV] ............... learning_rate=0.01, n_estimators=1, total=   0.1s
# [CV] learning_rate=0.01, n_estimators=3 ..............................
# [CV] ............... learning_rate=0.01, n_estimators=3, total=   0.2s
# [CV] learning_rate=0.01, n_estimators=3 ..............................
# [CV] ............... learning_rate=0.01, n_estimators=3, total=   0.2s
# [CV] ............. learning_rate=0.001, n_estimators=15, total=   1.1s
# [CV] learning_rate=0.01, n_estimators=3 ..............................
# [CV] learning_rate=0.01, n_estimators=3 ..............................
# [CV] ............... learning_rate=0.01, n_estimators=3, total=   0.2s
# [CV] learning_rate=0.01, n_estimators=5 ..............................
# [CV] ............... learning_rate=0.01, n_estimators=3, total=   0.2s
# [CV] learning_rate=0.01, n_estimators=5 ..............................
# [CV] ............... learning_rate=0.01, n_estimators=3, total=   0.2s
# [CV] learning_rate=0.01, n_estimators=5 ..............................
# [CV] ............... learning_rate=0.01, n_estimators=5, total=   0.3s
# [CV] learning_rate=0.01, n_estimators=5 ..............................
# [CV] ............... learning_rate=0.01, n_estimators=5, total=   0.3s
# [CV] learning_rate=0.01, n_estimators=5 ..............................
# [CV] ............... learning_rate=0.01, n_estimators=5, total=   0.4s
# [CV] learning_rate=0.01, n_estimators=7 ..............................
# [CV] ............. learning_rate=0.001, n_estimators=15, total=   1.3s
# [CV] learning_rate=0.01, n_estimators=7 ..............................
# [CV] ............... learning_rate=0.01, n_estimators=5, total=   0.3s
# [CV] learning_rate=0.01, n_estimators=7 ..............................
# [CV] ............... learning_rate=0.01, n_estimators=5, total=   0.4s
# [CV] learning_rate=0.01, n_estimators=7 ..............................
# [CV] ............... learning_rate=0.01, n_estimators=7, total=   0.5s
# [CV] learning_rate=0.01, n_estimators=7 ..............................
# [CV] ............... learning_rate=0.01, n_estimators=7, total=   0.5s
# [CV] learning_rate=0.01, n_estimators=9 ..............................
# [CV] ............... learning_rate=0.01, n_estimators=7, total=   0.5s
# [CV] learning_rate=0.01, n_estimators=9 ..............................
# [CV] ............... learning_rate=0.01, n_estimators=7, total=   0.5s
# [CV] learning_rate=0.01, n_estimators=9 ..............................
# [CV] ............... learning_rate=0.01, n_estimators=7, total=   0.4s
# [CV] learning_rate=0.01, n_estimators=9 ..............................
# [CV] ............... learning_rate=0.01, n_estimators=9, total=   0.6s
# [CV] learning_rate=0.01, n_estimators=9 ..............................
# [CV] ............... learning_rate=0.01, n_estimators=9, total=   0.7s
# [CV] learning_rate=0.01, n_estimators=11 .............................
# [CV] ............... learning_rate=0.01, n_estimators=9, total=   0.6s
# [CV] learning_rate=0.01, n_estimators=11 .............................
# [CV] ............... learning_rate=0.01, n_estimators=9, total=   0.6s
# [CV] learning_rate=0.01, n_estimators=11 .............................
# [CV] ............... learning_rate=0.01, n_estimators=9, total=   0.6s
# [CV] learning_rate=0.01, n_estimators=11 .............................
# [CV] .............. learning_rate=0.01, n_estimators=11, total=   0.8s
# [CV] learning_rate=0.01, n_estimators=11 .............................
# [CV] .............. learning_rate=0.01, n_estimators=11, total=   0.7s
# [CV] learning_rate=0.01, n_estimators=13 .............................
# [CV] .............. learning_rate=0.01, n_estimators=11, total=   0.9s
# [CV] learning_rate=0.01, n_estimators=13 .............................
# [CV] .............. learning_rate=0.01, n_estimators=11, total=   0.8s
# [CV] learning_rate=0.01, n_estimators=13 .............................
# [CV] .............. learning_rate=0.01, n_estimators=11, total=   0.9s
# [CV] learning_rate=0.01, n_estimators=13 .............................
# [CV] .............. learning_rate=0.01, n_estimators=13, total=   0.9s
# [CV] learning_rate=0.01, n_estimators=13 .............................
# [CV] .............. learning_rate=0.01, n_estimators=13, total=   0.8s
# [CV] learning_rate=0.01, n_estimators=15 .............................
# [CV] .............. learning_rate=0.01, n_estimators=13, total=   0.9s
# [CV] learning_rate=0.01, n_estimators=15 .............................
# [CV] .............. learning_rate=0.01, n_estimators=13, total=   0.9s
# [CV] learning_rate=0.01, n_estimators=15 .............................
# [CV] .............. learning_rate=0.01, n_estimators=13, total=   0.8s
# [CV] learning_rate=0.01, n_estimators=15 .............................
# [CV] .............. learning_rate=0.01, n_estimators=15, total=   1.1s
# [CV] .............. learning_rate=0.01, n_estimators=15, total=   1.1s
# [CV] learning_rate=0.01, n_estimators=15 .............................
# [CV] learning_rate=0.1, n_estimators=1 ...............................
# [CV] ................ learning_rate=0.1, n_estimators=1, total=   0.1s
# [CV] learning_rate=0.1, n_estimators=1 ...............................
# [CV] ................ learning_rate=0.1, n_estimators=1, total=   0.1s
# [CV] learning_rate=0.1, n_estimators=1 ...............................
# [CV] ................ learning_rate=0.1, n_estimators=1, total=   0.1s
# [CV] learning_rate=0.1, n_estimators=1 ...............................
# [CV] ................ learning_rate=0.1, n_estimators=1, total=   0.1s
# [CV] learning_rate=0.1, n_estimators=1 ...............................
# [CV] .............. learning_rate=0.01, n_estimators=15, total=   1.1s
# [CV] learning_rate=0.1, n_estimators=3 ...............................
# [CV] ................ learning_rate=0.1, n_estimators=1, total=   0.1s
# [CV] learning_rate=0.1, n_estimators=3 ...............................
# [CV] .............. learning_rate=0.01, n_estimators=15, total=   1.2s
# [CV] learning_rate=0.1, n_estimators=3 ...............................
# [CV] ................ learning_rate=0.1, n_estimators=3, total=   0.3s
# [CV] learning_rate=0.1, n_estimators=3 ...............................
# [CV] ................ learning_rate=0.1, n_estimators=3, total=   0.3s
# [CV] learning_rate=0.1, n_estimators=3 ...............................
# [CV] ................ learning_rate=0.1, n_estimators=3, total=   0.2s
# [CV] learning_rate=0.1, n_estimators=5 ...............................
# [CV] ................ learning_rate=0.1, n_estimators=3, total=   0.3s
# [CV] learning_rate=0.1, n_estimators=5 ...............................
# [CV] ................ learning_rate=0.1, n_estimators=3, total=   0.3s
# [CV] learning_rate=0.1, n_estimators=5 ...............................
# [CV] .............. learning_rate=0.01, n_estimators=15, total=   1.2s
# [CV] learning_rate=0.1, n_estimators=5 ...............................
# [CV] ................ learning_rate=0.1, n_estimators=5, total=   0.4s
# [CV] learning_rate=0.1, n_estimators=5 ...............................
# [CV] ................ learning_rate=0.1, n_estimators=5, total=   0.4s
# [CV] learning_rate=0.1, n_estimators=7 ...............................
# [CV] ................ learning_rate=0.1, n_estimators=5, total=   0.4s
# [CV] learning_rate=0.1, n_estimators=7 ...............................
# [CV] ................ learning_rate=0.1, n_estimators=5, total=   0.5s
# [CV] learning_rate=0.1, n_estimators=7 ...............................
# [CV] ................ learning_rate=0.1, n_estimators=5, total=   0.4s
# [CV] learning_rate=0.1, n_estimators=7 ...............................
# [CV] ................ learning_rate=0.1, n_estimators=7, total=   0.6s
# [CV] learning_rate=0.1, n_estimators=7 ...............................
# [CV] ................ learning_rate=0.1, n_estimators=7, total=   0.5s
# [CV] learning_rate=0.1, n_estimators=9 ...............................
# [CV] ................ learning_rate=0.1, n_estimators=7, total=   0.5s
# [CV] learning_rate=0.1, n_estimators=9 ...............................
# [CV] ................ learning_rate=0.1, n_estimators=7, total=   0.6s
# [CV] learning_rate=0.1, n_estimators=9 ...............................
# [CV] ................ learning_rate=0.1, n_estimators=7, total=   0.5s
# [CV] learning_rate=0.1, n_estimators=9 ...............................
# [CV] ................ learning_rate=0.1, n_estimators=9, total=   0.6s
# [CV] learning_rate=0.1, n_estimators=9 ...............................
# [CV] ................ learning_rate=0.1, n_estimators=9, total=   0.7s
# [CV] learning_rate=0.1, n_estimators=11 ..............................
# [CV] ................ learning_rate=0.1, n_estimators=9, total=   0.8s
# [CV] learning_rate=0.1, n_estimators=11 ..............................
# [CV] ................ learning_rate=0.1, n_estimators=9, total=   0.7s
# [CV] learning_rate=0.1, n_estimators=11 ..............................
# [CV] ................ learning_rate=0.1, n_estimators=9, total=   0.7s
# [CV] learning_rate=0.1, n_estimators=11 ..............................
# [CV] ............... learning_rate=0.1, n_estimators=11, total=   0.8s
# [CV] learning_rate=0.1, n_estimators=11 ..............................
# [CV] ............... learning_rate=0.1, n_estimators=11, total=   0.9s
# [CV] learning_rate=0.1, n_estimators=13 ..............................
# [CV] ............... learning_rate=0.1, n_estimators=11, total=   0.9s
# [CV] learning_rate=0.1, n_estimators=13 ..............................
# [CV] ............... learning_rate=0.1, n_estimators=11, total=   0.8s
# [CV] learning_rate=0.1, n_estimators=13 ..............................
# [CV] ............... learning_rate=0.1, n_estimators=11, total=   0.9s
# [CV] learning_rate=0.1, n_estimators=13 ..............................
# [CV] ............... learning_rate=0.1, n_estimators=13, total=   1.0s
# [CV] learning_rate=0.1, n_estimators=13 ..............................
# [CV] ............... learning_rate=0.1, n_estimators=13, total=   1.0s
# [CV] learning_rate=0.1, n_estimators=15 ..............................
# [CV] ............... learning_rate=0.1, n_estimators=13, total=   1.0s
# [CV] learning_rate=0.1, n_estimators=15 ..............................
# [CV] ............... learning_rate=0.1, n_estimators=13, total=   1.0s
# [CV] learning_rate=0.1, n_estimators=15 ..............................
# [CV] ............... learning_rate=0.1, n_estimators=13, total=   1.0s
# [CV] learning_rate=0.1, n_estimators=15 ..............................
# [CV] ............... learning_rate=0.1, n_estimators=15, total=   1.1s
# [CV] learning_rate=0.1, n_estimators=15 ..............................
# [CV] ............... learning_rate=0.1, n_estimators=15, total=   1.2s
# [CV] ............... learning_rate=0.1, n_estimators=15, total=   1.1s
# [CV] ............... learning_rate=0.1, n_estimators=15, total=   1.0s
# [CV] ............... learning_rate=0.1, n_estimators=15, total=   0.9s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:   18.9s finished
# GridSearchCV(cv=5, error_score='raise',
#        estimator=AdaBoostRegressor(base_estimator=None, learning_rate=1.0, loss='linear',
#          n_estimators=50, random_state=42),
#        fit_params=None, iid=True, n_jobs=-1,
#        param_grid={'learning_rate': array([0.001, 0.01 , 0.1  ]), 'n_estimators': range(1, 16, 2)},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=2)

# %%
print("Best estimators: ", ada_cv.best_params_)
print("Test set RMSE: ", math.sqrt(mean_squared_error(y_test, ada_cv.predict(x_test))))
# Out:
# Best estimators:  {'learning_rate': 0.01, 'n_estimators': 5}
# Test set RMSE:  97.42889581478566

# %% [markdown]
# # Problem 2 - Random Forest vs Boosting - Classification (15 pts)
# In this question, we will compare performance of different ensemble methods for classification problems: [Random Forest](http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html), [Gradient Boosting Decision Tree](http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.GradientBoostingClassifier.html) (GBDT), and [AdaBoost](http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.AdaBoostClassifier.html#sklearn.ensemble.AdaBoostClassifier). As in HW4, you will be classifying signal vs background in the MAGIC Gamma Telescope Data Set. The data has been split into training and test as well as standardized for you.
#
# 1. Use a [Random Forest](http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html) for the classification. Set the random_state to 42. Find the best parameters (by varying *n_estimators* and *criterion*) using [GridSearchCV](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html). Report your testing accuracy ([accuracy_score](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html)) and [roc_auc_score](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_auc_score.html#sklearn.metrics.roc_auc_score). You will need [predict_proba](http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html#sklearn.ensemble.RandomForestClassifier.predict_proba) for roc_auc_score. (4pts)
#
# 2. Use [Gradient Boosting Decision Tree](http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.GradientBoostingClassifier.html) (GBDT), and [AdaBoost](http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.AdaBoostClassifier.html#sklearn.ensemble.AdaBoostClassifier) for the spam classification problem. Again, find the best parameters (including *n_estimators, learning_rate,* and *max_depth (GBDT only)*), and report corresponding accuracy_score and roc_auc_score on the test data for each algorithm. (8pts)
#
# 3. Point out one advantage and one disadvantage of Random Forest compared to GBDT (3pts)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import (train_test_split,GridSearchCV)
from sklearn.metrics import (accuracy_score,roc_auc_score)
from sklearn.ensemble import (RandomForestClassifier,GradientBoostingClassifier,AdaBoostClassifier)
from sklearn import preprocessing

# %%
# load data
# train
train = pd.read_csv('magic_train.csv', header=None)
y_train = train.values[:,10]
y_train[y_train == 'g'] = 0
y_train[y_train == 'h'] = 1
y_train = y_train.astype(float)
x_train = train.values[:,:10]

# test
test = pd.read_csv('magic_test.csv', header=None)
y_test = test.values[:,10]
y_test[y_test == 'g'] = 0
y_test[y_test == 'h'] = 1
y_test = y_test.astype(float)
x_test = test.values[:,:10]

# standardize the data
x_train = preprocessing.scale(x_train)
x_test = preprocessing.scale(x_test)
# Out:
# /usr/local/lib/python2.7/dist-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype object was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# ## Solution
# ### Part a

# %%
params = {
    'n_estimators': range(1,500,50),
    'criterion': ['gini', 'entropy']
}
rand_forest_clf_cv = GridSearchCV(RandomForestClassifier(random_state=42), params, cv=5, verbose=2, n_jobs=-1)
rand_forest_clf_cv.fit(x_train, y_train)

# %%
print("Best estimators: ", rand_forest_clf_cv.best_params_)
print("Test set RMSE: ", mean_squared_error(y_test, rand_forest_clf_cv.predict(x_test)))

# %% [markdown]
# # Question 3: Visualization using Bokeh (10 pts)
#
# In this problem, you'll build an interactive visualization. Bokeh is a Python interactive visualization library that targets modern web browsers for presentation. For more information on Bokeh, see http://bokeh.pydata.org/en/latest/. The problem statement is as follows:
#
# Using the "nbasalaries_new.csv" data set, your goal is to build a Bokeh visualization which allows the user to explore how salary (on a log scale) varies with points per game (PSG) and age. You will create a visualization that allows the user to toggle the X axis of a scatter plot between PSG and age, with the y-axis always being log Salary. Also add the hover tool so that if the user hovers over a datapoint in the plot a window pops up that shows the player name, team, position, salary, and the current x variable (PSG or age) depending on the current tab.  Add the ability to Zoom in/out.
#
# Hints:
# 1. see: http://bokeh.pydata.org/en/latest/docs/user_guide/tools.html#basic-tooltips for hover and zoom tool examples.
# 2. See: http://bokeh.pydata.org/en/latest/docs/reference/plotting.html. Look for the scatter API.
# 3. See: http://bokeh.pydata.org/en/0.10.0/docs/user_guide/styling.html#labels. For labeling axes.
# 4. See: https://bokeh.pydata.org/en/latest/docs/user_guide/categorical.html  for how to use jitter transform
# 5. Use output_file() from Bokeh to output the plot to an external file. Submit this file as well.

# %%
import pandas as pd
import numpy as np
from bokeh.models.widgets import Panel, Tabs
from bokeh.models import CustomJS, ColumnDataSource, HoverTool, BoxZoomTool, Jitter
from bokeh.plotting import figure, output_notebook, show, output_file

data = pd.read_csv("nbasalaries_new.csv")
data["logsalary"] = data.SALARY.apply(np.log)

# %% [markdown]
# ## Solution
